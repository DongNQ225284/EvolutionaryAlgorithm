# %%
import numpy as np # type: ignore
import random
import matplotlib.pyplot as plt # type: ignore
import heapq

# %%
class Problem:
    def __init__(self, D, LB, UB):
        self.D = D
        self.LB = LB
        self.UB = UB

# %%
def decode(x_en, problem: Problem):
    x = x_en * (problem.UB - problem.LB) + problem.LB
    return x

def get_fitness(x):
    fx = np.sum(100 * (x[1:] - np.square(x[:-1]))**2 + (1 - np.square(x[:-1])))
    return -fx

# %%
class Individual:
    def __init__(self):
        self.chromosome = None
        self.fitness = None

    def genIndi(self, problem : Problem):
        self.chromosome = np.random.uniform(0.0, 1.0, problem.D)
    
    def cal_fitness(self, problem):
        sol = decode(self.chromosome, problem)
        self.fitness = get_fitness(sol)

    def __repr__(self):
        formatted_chromosome = np.array2string(self.chromosome, precision=2, separator=', ')
        return f"Individual(chromosome={formatted_chromosome}, fitness={self.fitness:.2f})"

# %%
# Simulated binary crossover - SBX
def crossover(parent1, parent2, problem : Problem, eta = 2.0):
    off1 = Individual()
    off2 = Individual()
    r = np.random.rand()
    if (r <= 0.5):
        beta = (2*r)**(1.0/(eta + 1))
    else:
        beta = (1.0/(2*(1 - r)))**(1.0/(eta + 1))
    p1 = parent1.chromosome
    p2 = parent2.chromosome
    c1 = 0.5 * ((1 + beta) * p1 + (1 - beta) * p2)
    c2 = 0.5 * ((1 - beta) * p1 + (1 + beta) * p2)
    c1 = np.clip(c1, 0.0, 1.0)
    c2 = np.clip(c2, 0.0, 1.0)
    off1.chromosome = c1
    off2.chromosome = c2
    return off1, off2

# Polynomial mutaion - PM
def mutation(indi, eta = 20.0):
    chr = indi.chromosome
    for i in range(chr.size):
        mu = np.random.rand()
        if (mu <= 0.5):
            delta = (2 * mu)**(1.0/(1 + eta)) - 1
            chr[i] = chr[i] + delta * chr[i]
        else:
            delta = 1 - (2 - 2*mu)**(1.0/(1 + eta))
            chr[i] = chr[i] + delta * (1 - chr[i])
            
    chr = np.clip(chr, 0.0, 1.0)
    indi.chromosome = chr
    return indi

# %%
class Population:
    def __init__(self, pop_size, problem : Problem):
        self.pop_size = pop_size
        self.list_indi = []
        self.problem = problem
    
    def genPop(self):
        for i in range(self.pop_size):
            indi = Individual()
            indi.genIndi(self.problem)
            indi.cal_fitness(self.problem)
            self.list_indi.append(indi)

# %%
def choice(list, k = 2):
    tour1 = random.sample(list, k)
    tour2 = random.sample(list, k)
    x = max(tour1, key=lambda indi: indi.fitness)
    y = max(tour2, key=lambda indi: indi.fitness)
    return x, y

# %%
def nextGen(list, pop_size):
    list = sorted(list, key=lambda indi: indi.fitness, reverse=True)
    list = list[0: pop_size]
    return list

# %%
def GA(problem, pop_size, max_gen, p_c, p_m):
    pop = Population(pop_size, problem)
    pop.genPop()
    history = []
    for i in range(max_gen):
        child = []
        while (len(child) < pop_size):
            p1, p2 = choice(pop.list_indi)
            if np.random.rand() <= p_c:
                c1, c2 = crossover(p1, p2, problem)
                c1.cal_fitness(problem)
                c2.cal_fitness(problem)
                child.append(c1)
                child.append(c2)
            if np.random.rand() <= p_m:
                p1 = mutation(p1)
                p2 = mutation(p2)
                p1.cal_fitness(problem)
                p2.cal_fitness(problem)
                child.append(p1)
                child.append(p2)
        pop.list_indi = nextGen(pop.list_indi + child, pop_size)
        history.append(pop.list_indi[0].fitness)
    return history

# %%
# setup
D = 10
LB = -50
UB = 50
problem = Problem(D, LB, UB)

pop_size = 200
Pc = 0.8
Pm = 0.2
max_gen = 501

# start
fitness_history = GA(problem, pop_size, max_gen, Pc, Pm)
for i in range(len(fitness_history)):
    print(f"Generation {i}, bestfitness = {fitness_history[i]:.2f}")
# Out:
# Generation 0, bestfitness = -61363431.58
# Generation 1, bestfitness = -12885672.64
# Generation 2, bestfitness = -4204686.55
# Generation 3, bestfitness = -3664984.12
# Generation 4, bestfitness = -2868629.41
# Generation 5, bestfitness = -1968013.53
# Generation 6, bestfitness = -467416.07
# Generation 7, bestfitness = -212272.40
# Generation 8, bestfitness = -85391.72
# Generation 9, bestfitness = -61493.81
# Generation 10, bestfitness = -47342.25
# Generation 11, bestfitness = -37739.41
# Generation 12, bestfitness = -30087.07
# Generation 13, bestfitness = -8663.48
# Generation 14, bestfitness = -8663.48
# Generation 15, bestfitness = -4349.57
# Generation 16, bestfitness = -3077.23
# Generation 17, bestfitness = -2954.10
# Generation 18, bestfitness = -2455.43
# Generation 19, bestfitness = -2029.54
# Generation 20, bestfitness = -2029.54
# Generation 21, bestfitness = -1756.42
# Generation 22, bestfitness = -1756.42
# Generation 23, bestfitness = -1803.61
# Generation 24, bestfitness = -1668.79
# Generation 25, bestfitness = -1665.44
# Generation 26, bestfitness = -1618.82
# Generation 27, bestfitness = -1556.83
# Generation 28, bestfitness = -1556.83
# Generation 29, bestfitness = -1404.00
# Generation 30, bestfitness = -1210.02
# Generation 31, bestfitness = -1190.85
# Generation 32, bestfitness = -1190.85
# Generation 33, bestfitness = -956.88
# Generation 34, bestfitness = -956.88
# Generation 35, bestfitness = -956.88
# Generation 36, bestfitness = -943.94
# Generation 37, bestfitness = -872.42
# Generation 38, bestfitness = -777.80
# Generation 39, bestfitness = -724.14
# Generation 40, bestfitness = -724.14
# Generation 41, bestfitness = -726.21
# Generation 42, bestfitness = -686.29
# Generation 43, bestfitness = -680.12
# Generation 44, bestfitness = -679.21
# Generation 45, bestfitness = -672.85
# Generation 46, bestfitness = -635.70
# Generation 47, bestfitness = -653.97
# Generation 48, bestfitness = -473.11
# Generation 49, bestfitness = -458.10
# Generation 50, bestfitness = -451.27
# Generation 51, bestfitness = -329.05
# Generation 52, bestfitness = -313.54
# Generation 53, bestfitness = -295.24
# Generation 54, bestfitness = -286.01
# Generation 55, bestfitness = -286.01
# Generation 56, bestfitness = -283.33
# Generation 57, bestfitness = -262.28
# Generation 58, bestfitness = -245.04
# Generation 59, bestfitness = -237.02
# Generation 60, bestfitness = -205.64
# Generation 61, bestfitness = -205.64
# Generation 62, bestfitness = -203.36
# Generation 63, bestfitness = -203.36
# Generation 64, bestfitness = -195.76
# Generation 65, bestfitness = -195.45
# Generation 66, bestfitness = -186.60
# Generation 67, bestfitness = -186.60
# Generation 68, bestfitness = -186.60
# Generation 69, bestfitness = -186.60
# Generation 70, bestfitness = -185.30
# Generation 71, bestfitness = -185.30
# Generation 334, bestfitness = -9.66
# Generation 335, bestfitness = -9.66
# Generation 336, bestfitness = -9.66
# Generation 337, bestfitness = -9.66
# Generation 338, bestfitness = -9.66
# Generation 339, bestfitness = -9.66
# Generation 340, bestfitness = -9.66
# Generation 341, bestfitness = -9.66
# Generation 342, bestfitness = -9.66
# Generation 343, bestfitness = -9.66
# Generation 344, bestfitness = -9.66
# Generation 345, bestfitness = -9.66
# Generation 346, bestfitness = -9.66
# Generation 347, bestfitness = -9.66
# Generation 348, bestfitness = -9.66
# Generation 349, bestfitness = -9.66
# Generation 350, bestfitness = -9.66
# Generation 351, bestfitness = -9.66
# Generation 352, bestfitness = -9.66
# Generation 353, bestfitness = -9.66
# Generation 354, bestfitness = -9.66
# Generation 355, bestfitness = -9.66
# Generation 356, bestfitness = -9.66
# Generation 357, bestfitness = -9.66
# Generation 358, bestfitness = -9.66
# Generation 359, bestfitness = -9.66
# Generation 360, bestfitness = -9.66
# Generation 361, bestfitness = -9.66
# Generation 362, bestfitness = -9.66
# Generation 363, bestfitness = -9.66
# Generation 364, bestfitness = -9.66
# Generation 365, bestfitness = -9.66
# Generation 366, bestfitness = -9.66
# Generation 367, bestfitness = -9.66
# Generation 368, bestfitness = -9.58
# Generation 369, bestfitness = -9.57
# Generation 370, bestfitness = -9.57
# Generation 371, bestfitness = -9.57
# Generation 372, bestfitness = -9.57
# Generation 373, bestfitness = -9.57
# Generation 374, bestfitness = -9.57
# Generation 375, bestfitness = -9.57
# Generation 376, bestfitness = -9.57
# Generation 377, bestfitness = -9.57
# Generation 378, bestfitness = -9.57
# Generation 379, bestfitness = -9.57
# Generation 380, bestfitness = -9.57
# Generation 381, bestfitness = -9.57
# Generation 382, bestfitness = -9.57
# Generation 383, bestfitness = -9.57
# Generation 384, bestfitness = -9.57
# Generation 385, bestfitness = -9.57
# Generation 386, bestfitness = -9.57
# Generation 387, bestfitness = -9.57
# Generation 388, bestfitness = -9.57
# Generation 389, bestfitness = -9.57
# Generation 390, bestfitness = -9.57
# Generation 391, bestfitness = -9.57
# Generation 392, bestfitness = -9.57
# Generation 393, bestfitness = -9.57
# Generation 394, bestfitness = -9.57
# Generation 395, bestfitness = -9.57
# Generation 396, bestfitness = -9.57
# Generation 397, bestfitness = -9.57
# Generation 398, bestfitness = -9.57
# Generation 399, bestfitness = -9.57
# Generation 400, bestfitness = -9.57
# Generation 401, bestfitness = -9.56
# Generation 402, bestfitness = -9.56
# Generation 403, bestfitness = -9.56
# Generation 404, bestfitness = -9.56
# Generation 405, bestfitness = -9.56
# Generation 406, bestfitness = -9.56
# Generation 407, bestfitness = -9.56
# Generation 408, bestfitness = -9.56
# Generation 409, bestfitness = -9.56
# Generation 410, bestfitness = -9.56
# Generation 411, bestfitness = -9.56
# Generation 412, bestfitness = -9.56
# Generation 413, bestfitness = -9.56
# Generation 414, bestfitness = -9.56
# Generation 415, bestfitness = -9.56
# Generation 416, bestfitness = -9.56
# Generation 417, bestfitness = -9.56
# Generation 418, bestfitness = -9.56
# Generation 419, bestfitness = -9.56
# Generation 420, bestfitness = -9.56
# Generation 421, bestfitness = -9.56
# Generation 422, bestfitness = -9.56
# Generation 423, bestfitness = -9.56
# Generation 424, bestfitness = -9.56
# Generation 425, bestfitness = -9.56
# Generation 426, bestfitness = -9.56
# Generation 427, bestfitness = -9.56
# Generation 428, bestfitness = -9.56
# Generation 429, bestfitness = -9.56
# Generation 430, bestfitness = -9.56
# Generation 431, bestfitness = -9.56
# Generation 432, bestfitness = -9.56
# Generation 433, bestfitness = -9.56
# Generation 434, bestfitness = -9.56
# Generation 435, bestfitness = -9.56
# Generation 436, bestfitness = -9.56
# Generation 437, bestfitness = -9.56
# Generation 438, bestfitness = -9.56
# Generation 439, bestfitness = -9.56
# Generation 440, bestfitness = -9.56
# Generation 441, bestfitness = -9.56
# Generation 442, bestfitness = -9.56
# Generation 443, bestfitness = -9.56
# Generation 444, bestfitness = -9.56
# Generation 445, bestfitness = -9.56
# Generation 446, bestfitness = -9.56
# Generation 447, bestfitness = -9.56
# Generation 448, bestfitness = -9.56
# Generation 449, bestfitness = -9.56
# Generation 450, bestfitness = -9.56
# Generation 451, bestfitness = -9.56
# Generation 452, bestfitness = -9.56
# Generation 453, bestfitness = -9.55
# Generation 454, bestfitness = -9.55
# Generation 455, bestfitness = -9.55
# Generation 456, bestfitness = -9.55
# Generation 457, bestfitness = -9.55
# Generation 458, bestfitness = -9.55
# Generation 459, bestfitness = -9.55
# Generation 460, bestfitness = -9.55
# Generation 461, bestfitness = -9.55
# Generation 462, bestfitness = -9.55
# Generation 463, bestfitness = -9.55
# Generation 464, bestfitness = -9.55
# Generation 465, bestfitness = -9.55
# Generation 466, bestfitness = -9.55
# Generation 467, bestfitness = -9.55
# Generation 468, bestfitness = -9.55
# Generation 469, bestfitness = -9.55
# Generation 470, bestfitness = -9.55
# Generation 471, bestfitness = -9.55
# Generation 472, bestfitness = -9.55
# Generation 473, bestfitness = -9.55
# Generation 474, bestfitness = -9.55
# Generation 475, bestfitness = -9.55
# Generation 476, bestfitness = -9.55
# Generation 477, bestfitness = -9.55
# Generation 478, bestfitness = -9.55
# Generation 479, bestfitness = -9.55
# Generation 480, bestfitness = -9.55
# Generation 481, bestfitness = -9.55
# Generation 482, bestfitness = -9.55
# Generation 483, bestfitness = -9.55
# Generation 484, bestfitness = -9.55
# Generation 485, bestfitness = -9.55
# Generation 486, bestfitness = -9.55
# Generation 487, bestfitness = -9.55
# Generation 488, bestfitness = -9.55
# Generation 489, bestfitness = -9.55
# Generation 490, bestfitness = -9.55
# Generation 491, bestfitness = -9.55
# Generation 492, bestfitness = -9.55
# Generation 493, bestfitness = -9.55
# Generation 494, bestfitness = -9.55
# Generation 495, bestfitness = -9.55
# Generation 496, bestfitness = -9.55
# Generation 497, bestfitness = -9.55
# Generation 498, bestfitness = -9.55
# Generation 499, bestfitness = -9.55
# Generation 500, bestfitness = -9.55

# %%
generations = list(range(len(fitness_history)))
plt.figure(figsize=(10, 5))
plt.plot(generations, fitness_history, marker='o', linestyle='-', color='b', label='Best Fitness')

plt.xlabel("Generation")
plt.ylabel("Best Fitness")
plt.title("Fitness Progress Over Generations")
plt.legend()
plt.grid(True)
plt.show()
