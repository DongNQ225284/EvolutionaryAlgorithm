# %%
import numpy as np # type: ignore
import random
import matplotlib.pyplot as plt # type: ignore
import heapq

# %%
class Problem:
    def __init__(self, D, LB, UB):
        self.D = D
        self.LB = LB
        self.UB = UB

# %%
def decode(x_en, problem: Problem):
    x = x_en * (problem.UB - problem.LB) + problem.LB
    return x

def get_fitness(x):
    fx = np.sum(100 * (x[1:] - np.square(x[:-1]))**2 + (1 - np.square(x[:-1])))
    return -fx

# %%
class Individual:
    def __init__(self):
        self.chromosome = None
        self.fitness = None

    def genIndi(self, problem : Problem):
        self.chromosome = np.random.uniform(0.0, 1.0, problem.D)
    
    def cal_fitness(self, problem):
        sol = decode(self.chromosome, problem)
        self.fitness = get_fitness(sol)

    def __repr__(self):
        formatted_chromosome = np.array2string(self.chromosome, precision=2, separator=', ')
        return f"Individual(chromosome={formatted_chromosome}, fitness={self.fitness:.2f})"

# %%
problem = Problem(5, -50, 50)
indi = Individual()
indi.genIndi(problem)
indi.cal_fitness(problem)

x = decode(indi.chromosome, problem)

print(indi)
print(x)
# Out:
# Individual(chromosome=[0.38, 0.23, 0.48, 0.84, 0.66], fitness=-187933728.25)
# [-12.23164296 -27.34074657  -1.65236085  33.91024354  15.96501355]

# %%
# Simulated binary crossover - SBX
def crossover(parent1, parent2, problem : Problem, eta = 2.0):
    off1 = Individual()
    off2 = Individual()
    r = np.random.rand()
    if (r <= 0.5):
        beta = (2*r)**(1.0/(eta + 1))
    else:
        beta = (1.0/(2*(1 - r)))**(1.0/(eta + 1))
    p1 = parent1.chromosome
    p2 = parent2.chromosome
    c1 = 0.5 * ((1 + beta) * p1 + (1 - beta) * p2)
    c2 = 0.5 * ((1 - beta) * p1 + (1 + beta) * p2)
    c1 = np.clip(c1, 0.0, 1.0)
    c2 = np.clip(c2, 0.0, 1.0)
    off1.chromosome = c1
    off2.chromosome = c2
    return off1, off2

# Polynomial mutaion - PM
def mutation(indi, eta = 20.0):
    chr = indi.chromosome
    for i in range(chr.size):
        mu = np.random.rand()
        if (mu <= 0.5):
            delta = (2 * mu)**(1.0/(1 + eta)) - 1
            chr[i] = chr[i] + delta * chr[i]
        else:
            delta = 1 - (2 - 2*mu)**(1.0/(1 + eta))
            chr[i] = chr[i] + delta * (1 - chr[i])
            
    chr = np.clip(chr, 0.0, 1.0)
    indi.chromosome = chr
    return indi

# %%
problem = Problem(5, -50, 50)
x = Individual()
x.genIndi(problem)
x.cal_fitness(problem)

y = Individual()
y.genIndi(problem)
y.cal_fitness(problem)

c1, c2 = crossover(x, y, problem)
c1.cal_fitness(problem)
c2.cal_fitness(problem)

c3 = mutation(x)
c4 = mutation(y)
c3.cal_fitness(problem)
c4.cal_fitness(problem)

print(x)
print(y)
print(c1)
print(c2)
print(c3)
print(c4)
# Out:
# Individual(chromosome=[0.02, 0.18, 0.8 , 0.67, 0.19], fitness=-739865479.36)
# Individual(chromosome=[0.87, 0.61, 0.78, 0.1 , 0.71], fitness=-510197042.90)
# Individual(chromosome=[0.07, 0.22, 0.79, 0.66, 0.22], fitness=-475614109.73)
# Individual(chromosome=[0.84, 0.76, 0.78, 0.14, 0.67], fitness=-399123003.81)
# Individual(chromosome=[0.02, 0.18, 0.8 , 0.67, 0.19], fitness=-739865479.36)
# Individual(chromosome=[0.87, 0.61, 0.78, 0.1 , 0.71], fitness=-510197042.90)

# %%
class Population:
    def __init__(self, pop_size, problem : Problem):
        self.pop_size = pop_size
        self.list_indi = []
        self.problem = problem
    
    def genPop(self):
        for i in range(self.pop_size):
            indi = Individual()
            indi.genIndi(self.problem)
            indi.cal_fitness(self.problem)
            self.list_indi.append(indi)

    def __repr__(self):
        pass

# %%
def choice(list, k = 2):
    tour1 = random.sample(list, k)
    tour2 = random.sample(list, k)
    x = max(tour1, key=lambda indi: indi.fitness)
    y = max(tour2, key=lambda indi: indi.fitness)
    return x, y

# %%
def nextGen(list, pop_size):
    list = sorted(list, key=lambda indi: indi.fitness, reverse=True)
    list = list[0: pop_size]
    # print(f"bestfitness = {list[0].fitness:.2f}")
    # for i in range(len(list)):
    #     print(f"indi[{i}], fitness = {list[i].fitness:.2f}")
    # print("============")
    return list

# %%
def GA(problem, pop_size, max_gen, p_c, p_m):
    pop = Population(pop_size, problem)
    pop.genPop()
    history = []
    for i in range(max_gen):
        child = []
        while (len(child) < pop_size):
            p1, p2 = choice(pop.list_indi)
            if np.random.rand() <= p_c:
                c1, c2 = crossover(p1, p2, problem)
                c1.cal_fitness(problem)
                c2.cal_fitness(problem)
                child.append(c1)
                child.append(c2)
            if np.random.rand() <= p_m:
                p1 = mutation(p1)
                p2 = mutation(p2)
                p1.cal_fitness(problem)
                p2.cal_fitness(problem)
                child.append(p1)
                child.append(p2)
        pop.list_indi = nextGen(pop.list_indi + child, pop_size)
        history.append(pop.list_indi[0].fitness)
    return history

# %%
# setup
D = 10
LB = -50
UB = 50
problem = Problem(D, LB, UB)

pop_size = 200
Pc = 0.8
Pm = 0.2
max_gen = 501

# start
fitness_history = GA(problem, pop_size, max_gen, Pc, Pm)
for i in range(len(fitness_history)):
    print(f"Generation {i}, bestfitness = {fitness_history[i]:.2f}")
# Out:
# Generation 0, bestfitness = -96936315.51
# Generation 1, bestfitness = -8758266.45
# Generation 2, bestfitness = -6717990.57
# Generation 3, bestfitness = -3600672.10
# Generation 4, bestfitness = -1124655.27
# Generation 5, bestfitness = -421054.52
# Generation 6, bestfitness = -421054.52
# Generation 7, bestfitness = -420699.10
# Generation 8, bestfitness = -250522.63
# Generation 9, bestfitness = -148378.02
# Generation 10, bestfitness = -130332.29
# Generation 11, bestfitness = -56141.49
# Generation 12, bestfitness = -47711.27
# Generation 13, bestfitness = -34822.19
# Generation 14, bestfitness = -22084.47
# Generation 15, bestfitness = -22084.47
# Generation 16, bestfitness = -8527.00
# Generation 17, bestfitness = -8409.20
# Generation 18, bestfitness = -8748.29
# Generation 345, bestfitness = -18.63
# Generation 346, bestfitness = -18.63
# Generation 347, bestfitness = -18.62
# Generation 348, bestfitness = -18.63
# Generation 349, bestfitness = -18.54
# Generation 350, bestfitness = -18.54
# Generation 351, bestfitness = -18.54
# Generation 352, bestfitness = -18.54
# Generation 353, bestfitness = -18.54
# Generation 354, bestfitness = -17.49
# Generation 355, bestfitness = -17.46
# Generation 356, bestfitness = -17.46
# Generation 357, bestfitness = -17.47
# Generation 358, bestfitness = -17.21
# Generation 359, bestfitness = -17.20
# Generation 360, bestfitness = -17.21
# Generation 361, bestfitness = -17.19
# Generation 362, bestfitness = -17.21
# Generation 363, bestfitness = -17.20
# Generation 364, bestfitness = -17.20
# Generation 365, bestfitness = -17.19
# Generation 366, bestfitness = -17.18
# Generation 367, bestfitness = -17.17
# Generation 368, bestfitness = -17.17
# Generation 369, bestfitness = -17.16
# Generation 370, bestfitness = -17.16
# Generation 371, bestfitness = -17.15
# Generation 372, bestfitness = -17.14
# Generation 373, bestfitness = -17.14
# Generation 374, bestfitness = -17.14
# Generation 375, bestfitness = -17.10
# Generation 376, bestfitness = -17.11
# Generation 377, bestfitness = -17.10
# Generation 378, bestfitness = -17.09
# Generation 379, bestfitness = -17.08
# Generation 380, bestfitness = -17.05
# Generation 381, bestfitness = -17.06
# Generation 382, bestfitness = -17.06
# Generation 383, bestfitness = -17.06
# Generation 384, bestfitness = -17.06
# Generation 385, bestfitness = -17.06
# Generation 386, bestfitness = -17.06
# Generation 387, bestfitness = -17.05
# Generation 388, bestfitness = -17.05
# Generation 389, bestfitness = -17.05
# Generation 390, bestfitness = -17.05
# Generation 391, bestfitness = -17.05
# Generation 392, bestfitness = -17.05
# Generation 393, bestfitness = -17.05
# Generation 394, bestfitness = -14.86
# Generation 395, bestfitness = -14.86
# Generation 396, bestfitness = -14.29
# Generation 397, bestfitness = -14.22
# Generation 398, bestfitness = -14.19
# Generation 399, bestfitness = -14.19
# Generation 400, bestfitness = -14.16
# Generation 401, bestfitness = -14.04
# Generation 402, bestfitness = -13.96
# Generation 403, bestfitness = -13.97
# Generation 404, bestfitness = -14.01
# Generation 405, bestfitness = -13.97
# Generation 406, bestfitness = -13.95
# Generation 407, bestfitness = -13.93
# Generation 408, bestfitness = -13.91
# Generation 409, bestfitness = -13.83
# Generation 410, bestfitness = -13.80
# Generation 411, bestfitness = -13.77
# Generation 412, bestfitness = -13.73
# Generation 413, bestfitness = -13.74
# Generation 414, bestfitness = -13.74
# Generation 415, bestfitness = -13.72
# Generation 416, bestfitness = -13.65
# Generation 417, bestfitness = -13.65
# Generation 418, bestfitness = -13.67
# Generation 419, bestfitness = -13.62
# Generation 420, bestfitness = -13.62
# Generation 421, bestfitness = -13.60
# Generation 422, bestfitness = -13.60
# Generation 423, bestfitness = -13.58
# Generation 424, bestfitness = -12.25
# Generation 425, bestfitness = -11.62
# Generation 426, bestfitness = -11.62
# Generation 427, bestfitness = -11.55
# Generation 428, bestfitness = -11.31
# Generation 429, bestfitness = -11.10
# Generation 430, bestfitness = -11.09
# Generation 431, bestfitness = -11.07
# Generation 432, bestfitness = -11.07
# Generation 433, bestfitness = -11.06
# Generation 434, bestfitness = -11.06
# Generation 435, bestfitness = -11.06
# Generation 436, bestfitness = -11.06
# Generation 437, bestfitness = -10.87
# Generation 438, bestfitness = -11.05
# Generation 439, bestfitness = -11.05
# Generation 440, bestfitness = -11.05
# Generation 441, bestfitness = -11.05
# Generation 442, bestfitness = -11.05
# Generation 443, bestfitness = -11.05
# Generation 444, bestfitness = -11.05
# Generation 445, bestfitness = -11.05
# Generation 446, bestfitness = -11.05
# Generation 447, bestfitness = -11.05
# Generation 448, bestfitness = -11.05
# Generation 449, bestfitness = -11.05
# Generation 450, bestfitness = -11.05
# Generation 451, bestfitness = -11.05
# Generation 452, bestfitness = -11.05
# Generation 453, bestfitness = -11.04
# Generation 454, bestfitness = -11.04
# Generation 455, bestfitness = -11.04
# Generation 456, bestfitness = -11.04
# Generation 457, bestfitness = -11.04
# Generation 458, bestfitness = -11.04
# Generation 459, bestfitness = -11.04
# Generation 460, bestfitness = -11.03
# Generation 461, bestfitness = -11.03
# Generation 462, bestfitness = -10.28
# Generation 463, bestfitness = -10.22
# Generation 464, bestfitness = -10.21
# Generation 465, bestfitness = -10.21
# Generation 466, bestfitness = -10.21
# Generation 467, bestfitness = -10.21
# Generation 468, bestfitness = -10.21
# Generation 469, bestfitness = -10.20
# Generation 470, bestfitness = -10.07
# Generation 471, bestfitness = -10.07
# Generation 472, bestfitness = -10.07
# Generation 473, bestfitness = -10.06
# Generation 474, bestfitness = -9.75
# Generation 475, bestfitness = -9.67
# Generation 476, bestfitness = -9.67
# Generation 477, bestfitness = -9.67
# Generation 478, bestfitness = -9.61
# Generation 479, bestfitness = -9.60
# Generation 480, bestfitness = -9.60
# Generation 481, bestfitness = -9.60
# Generation 482, bestfitness = -9.59
# Generation 483, bestfitness = -9.59
# Generation 484, bestfitness = -9.59
# Generation 485, bestfitness = -9.58
# Generation 486, bestfitness = -9.58
# Generation 487, bestfitness = -9.58
# Generation 488, bestfitness = -9.58
# Generation 489, bestfitness = -9.58
# Generation 490, bestfitness = -9.57
# Generation 491, bestfitness = -9.57
# Generation 492, bestfitness = -9.57
# Generation 493, bestfitness = -9.57
# Generation 494, bestfitness = -9.57
# Generation 495, bestfitness = -9.57
# Generation 496, bestfitness = -9.56
# Generation 497, bestfitness = -9.56
# Generation 498, bestfitness = -9.56
# Generation 499, bestfitness = -9.56
# Generation 500, bestfitness = -9.56

# %%
generations = list(range(len(fitness_history)))
plt.figure(figsize=(10, 5))
plt.plot(generations, fitness_history, marker='o', linestyle='-', color='b', label='Best Fitness')

plt.xlabel("Generation")
plt.ylabel("Best Fitness")
plt.title("Fitness Progress Over Generations")
plt.legend()
plt.grid(True)
plt.show()
