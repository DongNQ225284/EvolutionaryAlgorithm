# %% [markdown]
# ### Tối ưu hàm Rosenbrock
# Đầu vào:
# - Hàm Rosenbrock: $f_x = \sum_{i = 1}^{D - 1}{[100(x_{i + 1} - x_i^2)^2 + (1 - x_i)^2]}$
# - Số chiều: D
# - $x_i \in [lower, upper]$ với $i = [1...D]$
#
# Đầu ra:
# - Một lời giải $x = (x_1, x_2, ..., x_D)$
# - Giá trị nhỏ nhất $f_x$

# %%
import numpy as np # type: ignore
import random
import matplotlib.pyplot as plt # type: ignore

# %%
class Problem:
    def __init__(self, D, LB, UB):
        self.D = D
        self.LB = LB
        self.UB = UB

# %%
def decode(x_en, problem: Problem):
    x = x_en * (problem.UB - problem.LB) + problem.LB
    return x

def get_fitness(x):
    fx = np.sum(x**2)
    # fx = np.sum(100 * (x[1:] - np.square(x[:-1]))**2 + (1 - np.square(x[:-1])))
    return -fx

# %%
a = np.array([1, 2, 3, 4])
a = a**2
print(a)
print(np.sum(a))
# Out:
# [ 1  4  9 16]
# 30

# %%
class Individual:
    def __init__(self):
        self.chromosome = None
        self.fitness = None

    def genIndi(self, problem : Problem):
        self.chromosome = np.random.uniform(0.0, 1.0, problem.D)
    
    def cal_fitness(self, problem):
        sol = decode(self.chromosome, problem)
        self.fitness = get_fitness(sol)

    def __repr__(self):
        return f"chromosome={self.chromosome}, fitness={self.fitness:.2f})"

# %%
# Simulated binary crossover - SBX
def crossover(parent1, parent2, problem : Problem, eta = 2.0):
    off1 = Individual()
    off2 = Individual()
    r = np.random.rand()
    if (r <= 0.5):
        beta = (2*r)**(1.0/(eta + 1))
    else:
        beta = (1.0/(2*(1 - r)))**(1.0/(eta + 1))
    p1 = parent1.chromosome
    p2 = parent2.chromosome
    c1 = 0.5 * ((1 + beta) * p1 + (1 - beta) * p2)
    c2 = 0.5 * ((1 - beta) * p1 + (1 + beta) * p2)
    c1 = np.clip(c1, 0.0, 1.0)
    c2 = np.clip(c2, 0.0, 1.0)
    off1.chromosome = c1
    off2.chromosome = c2
    return off1, off2

# Polynomial mutaion - PM
def mutation(indi, eta = 20.0):
    chr = indi.chromosome
    for i in range(chr.size):
        mu = np.random.rand()
        if (mu <= 0.5):
            delta = (2 * mu)**(1.0/(1 + eta)) - 1
            chr[i] = chr[i] + delta * chr[i]
        else:
            delta = 1 - (2 - 2*mu)**(1.0/(1 + eta))
            chr[i] = chr[i] + delta * (1 - chr[i])
            
    chr = np.clip(chr, 0.0, 1.0)
    indi.chromosome = chr
    return indi

# %%
class Population:
    def __init__(self, pop_size, problem : Problem):
        self.pop_size = pop_size
        self.list_indi = []
        self.problem = problem
    
    def genPop(self):
        for i in range(self.pop_size):
            indi = Individual()
            indi.genIndi(self.problem)
            indi.cal_fitness(self.problem)
            self.list_indi.append(indi)

# %%
def choice(list, k = 2):
    tour1 = random.sample(list, k)
    tour2 = random.sample(list, k)
    x = max(tour1, key=lambda indi: indi.fitness)
    y = max(tour2, key=lambda indi: indi.fitness)
    return x, y

# %%
def nextGen(list, pop_size):
    list = sorted(list, key=lambda indi: indi.fitness, reverse=True)
    list = list[0: pop_size]
    return list

# %%
def GA(problem, pop_size, max_gen, p_c, p_m):
    pop = Population(pop_size, problem)
    pop.genPop()
    history = []
    for i in range(max_gen):
        child = []
        while (len(child) < pop_size):
            p1, p2 = choice(pop.list_indi)
            if np.random.rand() <= p_c:
                c1, c2 = crossover(p1, p2, problem)
                c1.cal_fitness(problem)
                c2.cal_fitness(problem)
                child.append(c1)
                child.append(c2)
            if np.random.rand() <= p_m:
                p1 = mutation(p1)
                p2 = mutation(p2)
                p1.cal_fitness(problem)
                p2.cal_fitness(problem)
                child.append(p1)
                child.append(p2)
        pop.list_indi = nextGen(pop.list_indi + child, pop_size)
        history.append(pop.list_indi[0].fitness)
    solution = pop.list_indi[0]
    return history, solution

# %%
# setup
D = 10
LB = -50
UB = 50
problem = Problem(D, LB, UB)

pop_size = 200
max_gen = 500
Pc = 0.9
Pm = 0.2

# start
fitness_history, solution = GA(problem, pop_size, max_gen, Pc, Pm)

#show
for i in range(len(fitness_history)):
    print(f"Generation {i}, bestfitness = {fitness_history[i]:.2f}")
# Out:
# Generation 0, bestfitness = -1773.67
# Generation 1, bestfitness = -1159.40
# Generation 2, bestfitness = -438.37
# Generation 3, bestfitness = -379.93
# Generation 4, bestfitness = -296.60
# Generation 5, bestfitness = -231.52
# Generation 6, bestfitness = -209.65
# Generation 7, bestfitness = -181.70
# Generation 8, bestfitness = -146.46
# Generation 9, bestfitness = -92.56
# Generation 10, bestfitness = -87.38
# Generation 11, bestfitness = -58.51
# Generation 12, bestfitness = -55.43
# Generation 13, bestfitness = -50.02
# Generation 14, bestfitness = -39.37
# Generation 15, bestfitness = -39.37
# Generation 16, bestfitness = -24.07
# Generation 17, bestfitness = -24.07
# Generation 18, bestfitness = -21.09
# Generation 19, bestfitness = -13.53
# Generation 20, bestfitness = -13.53
# Generation 21, bestfitness = -10.06
# Generation 22, bestfitness = -9.51
# Generation 23, bestfitness = -6.30
# Generation 24, bestfitness = -6.41
# Generation 25, bestfitness = -6.23
# Generation 26, bestfitness = -6.23
# Generation 27, bestfitness = -6.04
# Generation 28, bestfitness = -5.44
# Generation 29, bestfitness = -5.44
# Generation 30, bestfitness = -5.44
# Generation 31, bestfitness = -5.44
# Generation 32, bestfitness = -5.05
# Generation 33, bestfitness = -4.99
# Generation 34, bestfitness = -4.78
# Generation 35, bestfitness = -4.76
# Generation 36, bestfitness = -4.60
# Generation 37, bestfitness = -3.33
# Generation 38, bestfitness = -3.33
# Generation 39, bestfitness = -3.24
# Generation 40, bestfitness = -3.13
# Generation 41, bestfitness = -3.11
# Generation 42, bestfitness = -3.07
# Generation 43, bestfitness = -2.98
# Generation 44, bestfitness = -2.78
# Generation 45, bestfitness = -2.79
# Generation 46, bestfitness = -2.80
# Generation 47, bestfitness = -2.77
# Generation 48, bestfitness = -2.77
# Generation 49, bestfitness = -2.77
# Generation 50, bestfitness = -2.73
# Generation 51, bestfitness = -2.47
# Generation 52, bestfitness = -2.47
# Generation 53, bestfitness = -2.47
# Generation 54, bestfitness = -2.45
# Generation 55, bestfitness = -2.45
# Generation 56, bestfitness = -2.44
# Generation 57, bestfitness = -2.26
# Generation 58, bestfitness = -2.27
# Generation 59, bestfitness = -2.23
# Generation 60, bestfitness = -2.23
# Generation 61, bestfitness = -2.23
# Generation 62, bestfitness = -2.13
# Generation 63, bestfitness = -2.12
# Generation 64, bestfitness = -2.12
# Generation 65, bestfitness = -2.06
# Generation 66, bestfitness = -2.11
# Generation 67, bestfitness = -2.08
# Generation 68, bestfitness = -2.08
# Generation 69, bestfitness = -2.07
# Generation 70, bestfitness = -2.07
# Generation 71, bestfitness = -2.07
# Generation 72, bestfitness = -2.07
# Generation 73, bestfitness = -2.06
# Generation 74, bestfitness = -2.06
# Generation 75, bestfitness = -2.06
# Generation 76, bestfitness = -2.06
# Generation 77, bestfitness = -2.06
# Generation 78, bestfitness = -2.04
# Generation 79, bestfitness = -2.05
# Generation 80, bestfitness = -2.01
# Generation 81, bestfitness = -1.99
# Generation 82, bestfitness = -1.88
# Generation 83, bestfitness = -1.88
# Generation 84, bestfitness = -1.88
# Generation 85, bestfitness = -1.85
# Generation 86, bestfitness = -1.85
# Generation 87, bestfitness = -1.85
# Generation 88, bestfitness = -1.74
# Generation 89, bestfitness = -1.74
# Generation 90, bestfitness = -1.74
# Generation 91, bestfitness = -1.72
# Generation 92, bestfitness = -1.72
# Generation 93, bestfitness = -1.54
# Generation 94, bestfitness = -1.41
# Generation 95, bestfitness = -1.41
# Generation 96, bestfitness = -1.41
# Generation 97, bestfitness = -1.38
# Generation 98, bestfitness = -1.31
# Generation 99, bestfitness = -1.27
# Generation 100, bestfitness = -1.23
# Generation 101, bestfitness = -1.20
# Generation 102, bestfitness = -0.58
# Generation 103, bestfitness = -0.58
# Generation 104, bestfitness = -0.58
# Generation 105, bestfitness = -0.55
# Generation 106, bestfitness = -0.55
# Generation 107, bestfitness = -0.55
# Generation 108, bestfitness = -0.55
# Generation 109, bestfitness = -0.52
# Generation 110, bestfitness = -0.51
# Generation 111, bestfitness = -0.44
# Generation 112, bestfitness = -0.44
# Generation 113, bestfitness = -0.44
# Generation 114, bestfitness = -0.41
# Generation 115, bestfitness = -0.40
# Generation 116, bestfitness = -0.38
# Generation 117, bestfitness = -0.38
# Generation 118, bestfitness = -0.38
# Generation 119, bestfitness = -0.36
# Generation 120, bestfitness = -0.34
# Generation 121, bestfitness = -0.29
# Generation 122, bestfitness = -0.29
# Generation 123, bestfitness = -0.28
# Generation 124, bestfitness = -0.28
# Generation 125, bestfitness = -0.28
# Generation 126, bestfitness = -0.26
# Generation 127, bestfitness = -0.26
# Generation 128, bestfitness = -0.21
# Generation 129, bestfitness = -0.21
# Generation 130, bestfitness = -0.20
# Generation 131, bestfitness = -0.20
# Generation 132, bestfitness = -0.16
# Generation 133, bestfitness = -0.20
# Generation 134, bestfitness = -0.19
# Generation 135, bestfitness = -0.19
# Generation 136, bestfitness = -0.16
# Generation 137, bestfitness = -0.16
# Generation 138, bestfitness = -0.16
# Generation 139, bestfitness = -0.16
# Generation 140, bestfitness = -0.16
# Generation 141, bestfitness = -0.15
# Generation 142, bestfitness = -0.15
# Generation 143, bestfitness = -0.15
# Generation 144, bestfitness = -0.14
# Generation 145, bestfitness = -0.14
# Generation 146, bestfitness = -0.14
# Generation 147, bestfitness = -0.14
# Generation 148, bestfitness = -0.12
# Generation 149, bestfitness = -0.11
# Generation 150, bestfitness = -0.11
# Generation 151, bestfitness = -0.10
# Generation 152, bestfitness = -0.10
# Generation 153, bestfitness = -0.10
# Generation 154, bestfitness = -0.10
# Generation 155, bestfitness = -0.10
# Generation 156, bestfitness = -0.09
# Generation 157, bestfitness = -0.09
# Generation 158, bestfitness = -0.09
# Generation 159, bestfitness = -0.09
# Generation 160, bestfitness = -0.09
# Generation 161, bestfitness = -0.09
# Generation 162, bestfitness = -0.09
# Generation 163, bestfitness = -0.09
# Generation 164, bestfitness = -0.09
# Generation 165, bestfitness = -0.09
# Generation 166, bestfitness = -0.09
# Generation 167, bestfitness = -0.09
# Generation 168, bestfitness = -0.09
# Generation 169, bestfitness = -0.09
# Generation 170, bestfitness = -0.09
# Generation 171, bestfitness = -0.09
# Generation 172, bestfitness = -0.09
# Generation 173, bestfitness = -0.09
# Generation 174, bestfitness = -0.09
# Generation 175, bestfitness = -0.09
# Generation 176, bestfitness = -0.09
# Generation 177, bestfitness = -0.09
# Generation 178, bestfitness = -0.09
# Generation 179, bestfitness = -0.09
# Generation 180, bestfitness = -0.09
# Generation 181, bestfitness = -0.09
# Generation 182, bestfitness = -0.09
# Generation 183, bestfitness = -0.09
# Generation 184, bestfitness = -0.09
# Generation 185, bestfitness = -0.09
# Generation 186, bestfitness = -0.08
# Generation 187, bestfitness = -0.07
# Generation 188, bestfitness = -0.07
# Generation 189, bestfitness = -0.07
# Generation 190, bestfitness = -0.07
# Generation 191, bestfitness = -0.07
# Generation 192, bestfitness = -0.07
# Generation 193, bestfitness = -0.07
# Generation 194, bestfitness = -0.07
# Generation 195, bestfitness = -0.07
# Generation 196, bestfitness = -0.07
# Generation 197, bestfitness = -0.07
# Generation 198, bestfitness = -0.07
# Generation 199, bestfitness = -0.07
# Generation 200, bestfitness = -0.07
# Generation 201, bestfitness = -0.07
# Generation 202, bestfitness = -0.07
# Generation 203, bestfitness = -0.07
# Generation 204, bestfitness = -0.07
# Generation 205, bestfitness = -0.07
# Generation 206, bestfitness = -0.07
# Generation 207, bestfitness = -0.07
# Generation 208, bestfitness = -0.06
# Generation 209, bestfitness = -0.06
# Generation 210, bestfitness = -0.06
# Generation 211, bestfitness = -0.06
# Generation 212, bestfitness = -0.05
# Generation 213, bestfitness = -0.05
# Generation 214, bestfitness = -0.05
# Generation 215, bestfitness = -0.05
# Generation 216, bestfitness = -0.05
# Generation 217, bestfitness = -0.05
# Generation 218, bestfitness = -0.05
# Generation 219, bestfitness = -0.05
# Generation 220, bestfitness = -0.05
# Generation 221, bestfitness = -0.05
# Generation 222, bestfitness = -0.05
# Generation 223, bestfitness = -0.05
# Generation 224, bestfitness = -0.05
# Generation 225, bestfitness = -0.05
# Generation 226, bestfitness = -0.04
# Generation 227, bestfitness = -0.04
# Generation 228, bestfitness = -0.04
# Generation 229, bestfitness = -0.04
# Generation 230, bestfitness = -0.04
# Generation 231, bestfitness = -0.04
# Generation 232, bestfitness = -0.04
# Generation 233, bestfitness = -0.04
# Generation 234, bestfitness = -0.04
# Generation 235, bestfitness = -0.04
# Generation 236, bestfitness = -0.04
# Generation 237, bestfitness = -0.04
# Generation 238, bestfitness = -0.04
# Generation 239, bestfitness = -0.04
# Generation 240, bestfitness = -0.04
# Generation 241, bestfitness = -0.04
# Generation 242, bestfitness = -0.04
# Generation 243, bestfitness = -0.04
# Generation 244, bestfitness = -0.04
# Generation 245, bestfitness = -0.04
# Generation 246, bestfitness = -0.04
# Generation 247, bestfitness = -0.04
# Generation 248, bestfitness = -0.04
# Generation 249, bestfitness = -0.04
# Generation 250, bestfitness = -0.04
# Generation 251, bestfitness = -0.04
# Generation 252, bestfitness = -0.04
# Generation 253, bestfitness = -0.04
# Generation 254, bestfitness = -0.04
# Generation 255, bestfitness = -0.04
# Generation 256, bestfitness = -0.04
# Generation 257, bestfitness = -0.04
# Generation 258, bestfitness = -0.04
# Generation 259, bestfitness = -0.04
# Generation 260, bestfitness = -0.04
# Generation 261, bestfitness = -0.04
# Generation 262, bestfitness = -0.04
# Generation 263, bestfitness = -0.04
# Generation 264, bestfitness = -0.04
# Generation 265, bestfitness = -0.04
# Generation 266, bestfitness = -0.04
# Generation 267, bestfitness = -0.04
# Generation 268, bestfitness = -0.04
# Generation 269, bestfitness = -0.04
# Generation 270, bestfitness = -0.04
# Generation 271, bestfitness = -0.04
# Generation 272, bestfitness = -0.04
# Generation 273, bestfitness = -0.04
# Generation 274, bestfitness = -0.04
# Generation 275, bestfitness = -0.04
# Generation 276, bestfitness = -0.04
# Generation 277, bestfitness = -0.04
# Generation 278, bestfitness = -0.04
# Generation 279, bestfitness = -0.04
# Generation 280, bestfitness = -0.04
# Generation 281, bestfitness = -0.03
# Generation 282, bestfitness = -0.03
# Generation 283, bestfitness = -0.03
# Generation 284, bestfitness = -0.04
# Generation 285, bestfitness = -0.04
# Generation 286, bestfitness = -0.04
# Generation 287, bestfitness = -0.04
# Generation 288, bestfitness = -0.04
# Generation 289, bestfitness = -0.04
# Generation 290, bestfitness = -0.04
# Generation 291, bestfitness = -0.04
# Generation 292, bestfitness = -0.04
# Generation 293, bestfitness = -0.03
# Generation 294, bestfitness = -0.03
# Generation 295, bestfitness = -0.03
# Generation 296, bestfitness = -0.03
# Generation 297, bestfitness = -0.03
# Generation 298, bestfitness = -0.03
# Generation 299, bestfitness = -0.03
# Generation 300, bestfitness = -0.03
# Generation 301, bestfitness = -0.03
# Generation 302, bestfitness = -0.03
# Generation 303, bestfitness = -0.03
# Generation 304, bestfitness = -0.03
# Generation 305, bestfitness = -0.03
# Generation 306, bestfitness = -0.03
# Generation 307, bestfitness = -0.03
# Generation 308, bestfitness = -0.03
# Generation 309, bestfitness = -0.03
# Generation 310, bestfitness = -0.03
# Generation 311, bestfitness = -0.03
# Generation 312, bestfitness = -0.03
# Generation 313, bestfitness = -0.03
# Generation 314, bestfitness = -0.03
# Generation 315, bestfitness = -0.03
# Generation 316, bestfitness = -0.03
# Generation 317, bestfitness = -0.03
# Generation 318, bestfitness = -0.03
# Generation 319, bestfitness = -0.03
# Generation 320, bestfitness = -0.03
# Generation 321, bestfitness = -0.03
# Generation 322, bestfitness = -0.03
# Generation 323, bestfitness = -0.03
# Generation 324, bestfitness = -0.03
# Generation 325, bestfitness = -0.03
# Generation 326, bestfitness = -0.03
# Generation 327, bestfitness = -0.03
# Generation 328, bestfitness = -0.03
# Generation 329, bestfitness = -0.03
# Generation 330, bestfitness = -0.03
# Generation 331, bestfitness = -0.02
# Generation 332, bestfitness = -0.02
# Generation 333, bestfitness = -0.02
# Generation 334, bestfitness = -0.02
# Generation 335, bestfitness = -0.02
# Generation 336, bestfitness = -0.02
# Generation 337, bestfitness = -0.02
# Generation 338, bestfitness = -0.02
# Generation 339, bestfitness = -0.02
# Generation 340, bestfitness = -0.02
# Generation 341, bestfitness = -0.02
# Generation 342, bestfitness = -0.02
# Generation 343, bestfitness = -0.02
# Generation 344, bestfitness = -0.02
# Generation 345, bestfitness = -0.02
# Generation 346, bestfitness = -0.02
# Generation 347, bestfitness = -0.02
# Generation 348, bestfitness = -0.02
# Generation 349, bestfitness = -0.02
# Generation 350, bestfitness = -0.02
# Generation 351, bestfitness = -0.02
# Generation 352, bestfitness = -0.02
# Generation 353, bestfitness = -0.02
# Generation 354, bestfitness = -0.02
# Generation 355, bestfitness = -0.02
# Generation 356, bestfitness = -0.02
# Generation 357, bestfitness = -0.02
# Generation 358, bestfitness = -0.02
# Generation 359, bestfitness = -0.02
# Generation 360, bestfitness = -0.02
# Generation 361, bestfitness = -0.02
# Generation 362, bestfitness = -0.02
# Generation 363, bestfitness = -0.02
# Generation 364, bestfitness = -0.02
# Generation 365, bestfitness = -0.02
# Generation 366, bestfitness = -0.02
# Generation 367, bestfitness = -0.02
# Generation 368, bestfitness = -0.02
# Generation 369, bestfitness = -0.02
# Generation 370, bestfitness = -0.02
# Generation 371, bestfitness = -0.02
# Generation 372, bestfitness = -0.02
# Generation 373, bestfitness = -0.02
# Generation 374, bestfitness = -0.02
# Generation 375, bestfitness = -0.02
# Generation 376, bestfitness = -0.02
# Generation 377, bestfitness = -0.02
# Generation 378, bestfitness = -0.02
# Generation 379, bestfitness = -0.02
# Generation 380, bestfitness = -0.02
# Generation 381, bestfitness = -0.02
# Generation 382, bestfitness = -0.02
# Generation 383, bestfitness = -0.02
# Generation 384, bestfitness = -0.01
# Generation 385, bestfitness = -0.01
# Generation 386, bestfitness = -0.01
# Generation 387, bestfitness = -0.01
# Generation 388, bestfitness = -0.01
# Generation 389, bestfitness = -0.01
# Generation 390, bestfitness = -0.01
# Generation 391, bestfitness = -0.01
# Generation 392, bestfitness = -0.01
# Generation 393, bestfitness = -0.01
# Generation 394, bestfitness = -0.01
# Generation 395, bestfitness = -0.01
# Generation 396, bestfitness = -0.01
# Generation 397, bestfitness = -0.01
# Generation 398, bestfitness = -0.01
# Generation 399, bestfitness = -0.01
# Generation 400, bestfitness = -0.01
# Generation 401, bestfitness = -0.01
# Generation 402, bestfitness = -0.01
# Generation 403, bestfitness = -0.01
# Generation 404, bestfitness = -0.01
# Generation 405, bestfitness = -0.01
# Generation 406, bestfitness = -0.01
# Generation 407, bestfitness = -0.01
# Generation 408, bestfitness = -0.01
# Generation 409, bestfitness = -0.01
# Generation 410, bestfitness = -0.01
# Generation 411, bestfitness = -0.01
# Generation 412, bestfitness = -0.01
# Generation 413, bestfitness = -0.01
# Generation 414, bestfitness = -0.01
# Generation 415, bestfitness = -0.01
# Generation 416, bestfitness = -0.01
# Generation 417, bestfitness = -0.01
# Generation 418, bestfitness = -0.01
# Generation 419, bestfitness = -0.01
# Generation 420, bestfitness = -0.01
# Generation 421, bestfitness = -0.01
# Generation 422, bestfitness = -0.01
# Generation 423, bestfitness = -0.01
# Generation 424, bestfitness = -0.01
# Generation 425, bestfitness = -0.01
# Generation 426, bestfitness = -0.01
# Generation 427, bestfitness = -0.01
# Generation 428, bestfitness = -0.01
# Generation 429, bestfitness = -0.01
# Generation 430, bestfitness = -0.01
# Generation 431, bestfitness = -0.01
# Generation 432, bestfitness = -0.01
# Generation 433, bestfitness = -0.01
# Generation 434, bestfitness = -0.01
# Generation 435, bestfitness = -0.01
# Generation 436, bestfitness = -0.01
# Generation 437, bestfitness = -0.01
# Generation 438, bestfitness = -0.01
# Generation 439, bestfitness = -0.01
# Generation 440, bestfitness = -0.01
# Generation 441, bestfitness = -0.01
# Generation 442, bestfitness = -0.01
# Generation 443, bestfitness = -0.01
# Generation 444, bestfitness = -0.01
# Generation 445, bestfitness = -0.01
# Generation 446, bestfitness = -0.01
# Generation 447, bestfitness = -0.01
# Generation 448, bestfitness = -0.01
# Generation 449, bestfitness = -0.01
# Generation 450, bestfitness = -0.01
# Generation 451, bestfitness = -0.01
# Generation 452, bestfitness = -0.01
# Generation 453, bestfitness = -0.01
# Generation 454, bestfitness = -0.01
# Generation 455, bestfitness = -0.01
# Generation 456, bestfitness = -0.01
# Generation 457, bestfitness = -0.01
# Generation 458, bestfitness = -0.01
# Generation 459, bestfitness = -0.01
# Generation 460, bestfitness = -0.01
# Generation 461, bestfitness = -0.01
# Generation 462, bestfitness = -0.01
# Generation 463, bestfitness = -0.01
# Generation 464, bestfitness = -0.01
# Generation 465, bestfitness = -0.01
# Generation 466, bestfitness = -0.01
# Generation 467, bestfitness = -0.01
# Generation 468, bestfitness = -0.01
# Generation 469, bestfitness = -0.01
# Generation 470, bestfitness = -0.01
# Generation 471, bestfitness = -0.01
# Generation 472, bestfitness = -0.01
# Generation 473, bestfitness = -0.01
# Generation 474, bestfitness = -0.01
# Generation 475, bestfitness = -0.01
# Generation 476, bestfitness = -0.01
# Generation 477, bestfitness = -0.01
# Generation 478, bestfitness = -0.01
# Generation 479, bestfitness = -0.01
# Generation 480, bestfitness = -0.01
# Generation 481, bestfitness = -0.01
# Generation 482, bestfitness = -0.01
# Generation 483, bestfitness = -0.01
# Generation 484, bestfitness = -0.01
# Generation 485, bestfitness = -0.01
# Generation 486, bestfitness = -0.01
# Generation 487, bestfitness = -0.01
# Generation 488, bestfitness = -0.01
# Generation 489, bestfitness = -0.01
# Generation 490, bestfitness = -0.01
# Generation 491, bestfitness = -0.01
# Generation 492, bestfitness = -0.01
# Generation 493, bestfitness = -0.01
# Generation 494, bestfitness = -0.01
# Generation 495, bestfitness = -0.01
# Generation 496, bestfitness = -0.01
# Generation 497, bestfitness = -0.01
# Generation 498, bestfitness = -0.01
# Generation 499, bestfitness = -0.01

# %%
np.set_printoptions(precision=2, suppress=True)
print("solution:")
print(decode(solution.chromosome, problem))
print(f"The Rosenbrock value is: {- solution.fitness:.2f}")
# Out:
# solution:
# [ 0.   -0.01  0.    0.    0.   -0.01 -0.01 -0.    0.    0.  ]
# The Rosenbrock value is: 0.00

# %%
generations = list(range(len(fitness_history)))
plt.figure(figsize=(10, 5))
plt.plot(generations, fitness_history, marker='o', linestyle='-', color='b', label='Best Fitness')

plt.xlabel("Generation")
plt.ylabel("Best Fitness")
plt.title("Fitness Progress Over Generations")
plt.legend()
plt.grid(True)
plt.show()
