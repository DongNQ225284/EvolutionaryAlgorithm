# %%
import numpy as np # type: ignore
import random
import matplotlib.pyplot as plt # type: ignore
import heapq

# %%
class Problem:
    def __init__(self, D, LB, UB):
        self.D = D
        self.LB = LB
        self.UB = UB

# %%
def decode(x_en, problem: Problem):
    x = x_en * (problem.UB - problem.LB) + problem.LB
    return x

def get_fitness(x):
    fx = np.sum(100 * (x[1:] - np.square(x[:-1]))**2 + (1 - np.square(x[:-1])))
    return -fx

# %%
class Individual:
    def __init__(self):
        self.chromosome = None
        self.fitness = None

    def genIndi(self, problem : Problem):
        self.chromosome = np.random.uniform(0.0, 1.0, problem.D)
    
    def cal_fitness(self, problem):
        sol = decode(self.chromosome, problem)
        self.fitness = get_fitness(sol)

    def __repr__(self):
        formatted_chromosome = np.array2string(self.chromosome, precision=2, separator=', ')
        return f"Individual(chromosome={formatted_chromosome}, fitness={self.fitness:.2f})"

# %%
# Simulated binary crossover - SBX
def crossover(parent1, parent2, problem : Problem, eta = 2.0):
    off1 = Individual()
    off2 = Individual()
    r = np.random.rand()
    if (r <= 0.5):
        beta = (2*r)**(1.0/(eta + 1))
    else:
        beta = (1.0/(2*(1 - r)))**(1.0/(eta + 1))
    p1 = parent1.chromosome
    p2 = parent2.chromosome
    c1 = 0.5 * ((1 + beta) * p1 + (1 - beta) * p2)
    c2 = 0.5 * ((1 - beta) * p1 + (1 + beta) * p2)
    c1 = np.clip(c1, 0.0, 1.0)
    c2 = np.clip(c2, 0.0, 1.0)
    off1.chromosome = c1
    off2.chromosome = c2
    return off1, off2

# Polynomial mutaion - PM
def mutation(indi, eta = 20.0):
    chr = indi.chromosome
    for i in range(chr.size):
        mu = np.random.rand()
        if (mu <= 0.5):
            delta = (2 * mu)**(1.0/(1 + eta)) - 1
            chr[i] = chr[i] + delta * chr[i]
        else:
            delta = 1 - (2 - 2*mu)**(1.0/(1 + eta))
            chr[i] = chr[i] + delta * (1 - chr[i])
            
    chr = np.clip(chr, 0.0, 1.0)
    indi.chromosome = chr
    return indi

# %%
class Population:
    def __init__(self, pop_size, problem : Problem):
        self.pop_size = pop_size
        self.list_indi = []
        self.problem = problem
    
    def genPop(self):
        for i in range(self.pop_size):
            indi = Individual()
            indi.genIndi(self.problem)
            indi.cal_fitness(self.problem)
            self.list_indi.append(indi)

# %%
def choice(list, k = 2):
    tour1 = random.sample(list, k)
    tour2 = random.sample(list, k)
    x = max(tour1, key=lambda indi: indi.fitness)
    y = max(tour2, key=lambda indi: indi.fitness)
    return x, y

# %%
def nextGen(list, pop_size):
    list = sorted(list, key=lambda indi: indi.fitness, reverse=True)
    list = list[0: pop_size]
    return list

# %%
def GA(problem, pop_size, max_gen, p_c, p_m):
    pop = Population(pop_size, problem)
    pop.genPop()
    history = []
    for i in range(max_gen):
        child = []
        while (len(child) < pop_size):
            p1, p2 = choice(pop.list_indi)
            if np.random.rand() <= p_c:
                c1, c2 = crossover(p1, p2, problem)
                c1.cal_fitness(problem)
                c2.cal_fitness(problem)
                child.append(c1)
                child.append(c2)
            if np.random.rand() <= p_m:
                p1 = mutation(p1)
                p2 = mutation(p2)
                p1.cal_fitness(problem)
                p2.cal_fitness(problem)
                child.append(p1)
                child.append(p2)
        pop.list_indi = nextGen(pop.list_indi + child, pop_size)
        history.append(pop.list_indi[0].fitness)
    return history

# %%
# setup
D = 10
LB = -50
UB = 50
problem = Problem(D, LB, UB)

pop_size = 200
Pc = 0.8
Pm = 0.2
max_gen = 501

# start
fitness_history = GA(problem, pop_size, max_gen, Pc, Pm)
for i in range(len(fitness_history)):
    print(f"Generation {i}, bestfitness = {fitness_history[i]:.2f}")
# Out:
# Generation 0, bestfitness = -57199319.75
# Generation 1, bestfitness = -10147453.41
# Generation 2, bestfitness = -9622054.34
# Generation 3, bestfitness = -4677971.67
# Generation 4, bestfitness = -2287650.56
# Generation 5, bestfitness = -590272.15
# Generation 6, bestfitness = -519395.25
# Generation 7, bestfitness = -387701.05
# Generation 8, bestfitness = -219858.81
# Generation 9, bestfitness = -176088.26
# Generation 10, bestfitness = -44588.48
# Generation 11, bestfitness = -44588.48
# Generation 12, bestfitness = -33314.05
# Generation 13, bestfitness = -14057.26
# Generation 14, bestfitness = -10741.26
# Generation 15, bestfitness = -7738.33
# Generation 16, bestfitness = -3114.33
# Generation 17, bestfitness = -3114.33
# Generation 18, bestfitness = -2728.11
# Generation 19, bestfitness = -2728.11
# Generation 20, bestfitness = -2728.11
# Generation 21, bestfitness = -2302.95
# Generation 22, bestfitness = -1917.93
# Generation 23, bestfitness = -1696.83
# Generation 24, bestfitness = -1587.26
# Generation 25, bestfitness = -1408.39
# Generation 26, bestfitness = -1408.39
# Generation 27, bestfitness = -1313.89
# Generation 28, bestfitness = -1313.89
# Generation 29, bestfitness = -1253.28
# Generation 30, bestfitness = -1253.14
# Generation 31, bestfitness = -1155.72
# Generation 32, bestfitness = -1146.42
# Generation 33, bestfitness = -1095.16
# Generation 34, bestfitness = -1128.45
# Generation 35, bestfitness = -1116.90
# Generation 36, bestfitness = -1097.38
# Generation 37, bestfitness = -1096.63
# Generation 38, bestfitness = -1076.11
# Generation 39, bestfitness = -1070.49
# Generation 40, bestfitness = -1059.06
# Generation 41, bestfitness = -1052.03
# Generation 42, bestfitness = -1040.86
# Generation 43, bestfitness = -1039.65
# Generation 44, bestfitness = -1020.13
# Generation 45, bestfitness = -1020.05
# Generation 46, bestfitness = -1020.13
# Generation 47, bestfitness = -1010.72
# Generation 48, bestfitness = -901.87
# Generation 49, bestfitness = -885.57
# Generation 50, bestfitness = -885.57
# Generation 51, bestfitness = -885.57
# Generation 52, bestfitness = -896.78
# Generation 53, bestfitness = -877.09
# Generation 54, bestfitness = -868.64
# Generation 55, bestfitness = -682.77
# Generation 56, bestfitness = -682.77
# Generation 57, bestfitness = -679.30
# Generation 58, bestfitness = -676.53
# Generation 59, bestfitness = -646.88
# Generation 60, bestfitness = -646.88
# Generation 61, bestfitness = -641.35
# Generation 62, bestfitness = -635.57
# Generation 63, bestfitness = -635.51
# Generation 64, bestfitness = -632.81
# Generation 65, bestfitness = -633.61
# Generation 66, bestfitness = -633.60
# Generation 67, bestfitness = -632.40
# Generation 68, bestfitness = -632.40
# Generation 69, bestfitness = -632.20
# Generation 70, bestfitness = -632.55
# Generation 334, bestfitness = -305.59
# Generation 335, bestfitness = -305.56
# Generation 336, bestfitness = -305.48
# Generation 337, bestfitness = -305.48
# Generation 338, bestfitness = -304.90
# Generation 339, bestfitness = -298.63
# Generation 340, bestfitness = -297.98
# Generation 341, bestfitness = -297.70
# Generation 342, bestfitness = -288.15
# Generation 343, bestfitness = -288.10
# Generation 344, bestfitness = -288.15
# Generation 345, bestfitness = -288.13
# Generation 346, bestfitness = -287.95
# Generation 347, bestfitness = -288.03
# Generation 348, bestfitness = -288.02
# Generation 349, bestfitness = -287.94
# Generation 350, bestfitness = -287.92
# Generation 351, bestfitness = -263.39
# Generation 352, bestfitness = -263.39
# Generation 353, bestfitness = -239.04
# Generation 354, bestfitness = -239.04
# Generation 355, bestfitness = -238.16
# Generation 356, bestfitness = -236.97
# Generation 357, bestfitness = -236.64
# Generation 358, bestfitness = -232.37
# Generation 359, bestfitness = -232.37
# Generation 360, bestfitness = -225.38
# Generation 361, bestfitness = -225.38
# Generation 362, bestfitness = -225.38
# Generation 363, bestfitness = -225.38
# Generation 364, bestfitness = -227.82
# Generation 365, bestfitness = -228.96
# Generation 366, bestfitness = -218.16
# Generation 367, bestfitness = -208.40
# Generation 368, bestfitness = -205.93
# Generation 369, bestfitness = -205.91
# Generation 370, bestfitness = -204.43
# Generation 371, bestfitness = -203.82
# Generation 372, bestfitness = -203.96
# Generation 373, bestfitness = -202.18
# Generation 374, bestfitness = -202.02
# Generation 375, bestfitness = -201.93
# Generation 376, bestfitness = -201.75
# Generation 377, bestfitness = -201.75
# Generation 378, bestfitness = -201.71
# Generation 379, bestfitness = -201.68
# Generation 380, bestfitness = -201.46
# Generation 381, bestfitness = -201.12
# Generation 382, bestfitness = -201.12
# Generation 383, bestfitness = -201.12
# Generation 384, bestfitness = -201.12
# Generation 385, bestfitness = -201.06
# Generation 386, bestfitness = -201.00
# Generation 387, bestfitness = -201.01
# Generation 388, bestfitness = -200.99
# Generation 389, bestfitness = -200.84
# Generation 390, bestfitness = -200.84
# Generation 391, bestfitness = -200.84
# Generation 392, bestfitness = -200.76
# Generation 393, bestfitness = -200.69
# Generation 394, bestfitness = -200.69
# Generation 395, bestfitness = -200.23
# Generation 396, bestfitness = -200.24
# Generation 397, bestfitness = -199.37
# Generation 398, bestfitness = -199.37
# Generation 399, bestfitness = -198.97
# Generation 400, bestfitness = -192.55
# Generation 401, bestfitness = -191.81
# Generation 402, bestfitness = -191.86
# Generation 403, bestfitness = -191.69
# Generation 404, bestfitness = -191.69
# Generation 405, bestfitness = -191.69
# Generation 406, bestfitness = -191.63
# Generation 407, bestfitness = -191.46
# Generation 408, bestfitness = -191.17
# Generation 409, bestfitness = -190.91
# Generation 410, bestfitness = -190.91
# Generation 411, bestfitness = -186.20
# Generation 412, bestfitness = -184.76
# Generation 413, bestfitness = -184.59
# Generation 414, bestfitness = -184.59
# Generation 415, bestfitness = -184.55
# Generation 416, bestfitness = -184.55
# Generation 417, bestfitness = -184.46
# Generation 418, bestfitness = -183.81
# Generation 419, bestfitness = -183.97
# Generation 420, bestfitness = -183.97
# Generation 421, bestfitness = -183.97
# Generation 422, bestfitness = -183.86
# Generation 423, bestfitness = -183.85
# Generation 424, bestfitness = -183.79
# Generation 425, bestfitness = -183.76
# Generation 426, bestfitness = -183.76
# Generation 427, bestfitness = -183.78
# Generation 428, bestfitness = -183.70
# Generation 429, bestfitness = -183.64
# Generation 430, bestfitness = -183.65
# Generation 431, bestfitness = -183.65
# Generation 432, bestfitness = -179.92
# Generation 433, bestfitness = -179.92
# Generation 434, bestfitness = -179.36
# Generation 435, bestfitness = -179.35
# Generation 436, bestfitness = -179.39
# Generation 437, bestfitness = -179.34
# Generation 438, bestfitness = -179.26
# Generation 439, bestfitness = -179.09
# Generation 440, bestfitness = -178.92
# Generation 441, bestfitness = -178.80
# Generation 442, bestfitness = -178.80
# Generation 443, bestfitness = -178.80
# Generation 444, bestfitness = -178.80
# Generation 445, bestfitness = -178.78
# Generation 446, bestfitness = -178.60
# Generation 447, bestfitness = -178.60
# Generation 448, bestfitness = -178.60
# Generation 449, bestfitness = -178.44
# Generation 450, bestfitness = -174.62
# Generation 451, bestfitness = -173.08
# Generation 452, bestfitness = -173.08
# Generation 453, bestfitness = -172.15
# Generation 454, bestfitness = -172.02
# Generation 455, bestfitness = -171.87
# Generation 456, bestfitness = -171.83
# Generation 457, bestfitness = -171.86
# Generation 458, bestfitness = -168.80
# Generation 459, bestfitness = -168.80
# Generation 460, bestfitness = -168.80
# Generation 461, bestfitness = -171.54
# Generation 462, bestfitness = -171.52
# Generation 463, bestfitness = -171.47
# Generation 464, bestfitness = -171.09
# Generation 465, bestfitness = -171.09
# Generation 466, bestfitness = -171.05
# Generation 467, bestfitness = -171.02
# Generation 468, bestfitness = -170.95
# Generation 469, bestfitness = -170.91
# Generation 470, bestfitness = -170.91
# Generation 471, bestfitness = -170.43
# Generation 472, bestfitness = -170.91
# Generation 473, bestfitness = -170.91
# Generation 474, bestfitness = -170.89
# Generation 475, bestfitness = -170.88
# Generation 476, bestfitness = -170.88
# Generation 477, bestfitness = -170.88
# Generation 478, bestfitness = -170.88
# Generation 479, bestfitness = -151.44
# Generation 480, bestfitness = -156.35
# Generation 481, bestfitness = -162.47
# Generation 482, bestfitness = -161.01
# Generation 483, bestfitness = -157.96
# Generation 484, bestfitness = -156.77
# Generation 485, bestfitness = -156.77
# Generation 486, bestfitness = -154.62
# Generation 487, bestfitness = -150.37
# Generation 488, bestfitness = -145.08
# Generation 489, bestfitness = -145.44
# Generation 490, bestfitness = -144.90
# Generation 491, bestfitness = -142.79
# Generation 492, bestfitness = -138.52
# Generation 493, bestfitness = -139.71
# Generation 494, bestfitness = -139.71
# Generation 495, bestfitness = -139.15
# Generation 496, bestfitness = -138.18
# Generation 497, bestfitness = -136.13
# Generation 498, bestfitness = -136.13
# Generation 499, bestfitness = -135.37
# Generation 500, bestfitness = -133.99

# %%
generations = list(range(len(fitness_history)))
plt.figure(figsize=(10, 5))
plt.plot(generations, fitness_history, marker='o', linestyle='-', color='b', label='Best Fitness')

plt.xlabel("Generation")
plt.ylabel("Best Fitness")
plt.title("Fitness Progress Over Generations")
plt.legend()
plt.grid(True)
plt.show()
