# %%
import numpy as np # type: ignore
import random
import matplotlib.pyplot as plt # type: ignore

# %%
class Problem:
    def __init__(self, profit, weight, capacity):
        self.profit = profit
        self.weight = weight
        self.capacity = capacity

# %%
def decode(chromosome):
    chr = chromosome.tolist()
    return np.array([0 if gen < 0.5 else 1 for gen in chr])

def get_fitness(chromosome, problem : Problem):
    solution = decode(chromosome)
    total_profit = np.sum(solution * problem.profit)
    total_weight = np.sum(solution * problem.weight)
    if total_weight > problem.capacity:
        return 0
    else:
        return total_profit

# %%
class Individual:
    def __init__(self):
        self.chromosome = None
        self.fitness = None

    def genIndi(self, problem : Problem):
        num_item = problem.profit.size
        self.chromosome = np.random.uniform(0.0, 1.0, num_item)
    
    def cal_fitness(self, problem : Problem):
        self.fitness = get_fitness(self.chromosome, problem)

    def __repr__(self):
        return f"chromosome={self.chromosome}, fitness={self.fitness}"

# %%
# Simulated binary crossover - SBX
def crossover(parent1, parent2, problem : Problem, eta = 2.0):
    off1 = Individual()
    off2 = Individual()
    r = np.random.rand()
    if (r <= 0.5):
        beta = (2*r)**(1.0/(eta + 1))
    else:
        beta = (1.0/(2*(1 - r)))**(1.0/(eta + 1))
    p1 = parent1.chromosome
    p2 = parent2.chromosome
    c1 = 0.5 * ((1 + beta) * p1 + (1 - beta) * p2)
    c2 = 0.5 * ((1 - beta) * p1 + (1 + beta) * p2)
    c1 = np.clip(c1, 0.0, 1.0)
    c2 = np.clip(c2, 0.0, 1.0)
    off1.chromosome = c1
    off2.chromosome = c2
    return off1, off2

# Polynomial mutaion - PM
def mutation(indi, eta = 20.0):
    chr = indi.chromosome
    for i in range(chr.size):
        mu = np.random.rand()
        if (mu <= 0.5):
            delta = (2 * mu)**(1.0/(1 + eta)) - 1
            chr[i] = chr[i] + delta * chr[i]
        else:
            delta = 1 - (2 - 2*mu)**(1.0/(1 + eta))
            chr[i] = chr[i] + delta * (1 - chr[i])
            
    chr = np.clip(chr, 0.0, 1.0)
    indi.chromosome = chr
    return indi

# %%
class Population:
    def __init__(self, pop_size, problem : Problem):
        self.pop_size = pop_size
        self.list_indi = []
        self.problem = problem
    
    def genPop(self):
        for i in range(self.pop_size):
            indi = Individual()
            indi.genIndi(self.problem)
            indi.cal_fitness(self.problem)
            self.list_indi.append(indi)

    def __repr__(self):
        pass

# %%
def choice(list, k = 2):
    tour1 = random.sample(list, k)
    tour2 = random.sample(list, k)
    x = max(tour1, key=lambda indi: indi.fitness)
    y = max(tour2, key=lambda indi: indi.fitness)
    return x, y

# %%
def nextGen(list, pop_size):
    list = sorted(list, key=lambda indi: indi.fitness, reverse=True)
    list = list[0: pop_size]
    return list

# %%
def GA(problem, pop_size, max_gen, p_c, p_m):
    pop = Population(pop_size, problem)
    pop.genPop()
    history = []
    for i in range(max_gen):
        nextPop = []
        while (len(nextPop) < pop_size):
            p1, p2 = choice(pop.list_indi)
            c1 = Individual()
            c2 = Individual()
            if np.random.rand() <= p_c:
                c1, c2 = crossover(p1, p2, problem)
                c1.cal_fitness(problem)
                c2.cal_fitness(problem)
                nextPop.append(c1)
                nextPop.append(c2)
            if np.random.rand() <= p_m:
                p1 = mutation(p1)
                p2 = mutation(p2)
                p1.cal_fitness(problem)
                p2.cal_fitness(problem)
                nextPop.append(p1)
                nextPop.append(p2)
        pop.list_indi = nextGen(nextPop, pop_size)
        # Make sure that pop.list_indi is sorted in the 'nextGen' function before adding it to history
        history.append(pop.list_indi[0].fitness)
    solution = pop.list_indi[0]
    return history, solution

# %%
# setup
profit = np.random.uniform(5.0, 20.0, 10)
weight = np.random.uniform(2.0, 20.0, 10)
capacity = np.random.uniform(0.0, np.sum(weight))
# profit = np.array([3, 6, 8, 10, 15])
# weight = np.array([2, 3, 3, 5, 8])
# capacity = 10
problem = Problem(profit, weight, capacity)

pop_size = 200
max_gen = 500
Pc = 0.8
Pm = 0.2

#start
fitness_history, solution = GA(problem, pop_size, max_gen, Pc, Pm)

#show
for i in range(len(fitness_history)):
    print(f"Generation {i}, bestfitness = {fitness_history[i]:.2f}")
# Out:
# Generation 0, bestfitness = 121.33
# Generation 1, bestfitness = 121.33
# Generation 2, bestfitness = 122.63
# Generation 3, bestfitness = 133.95
# Generation 4, bestfitness = 133.95
# Generation 5, bestfitness = 133.95
# Generation 6, bestfitness = 133.95
# Generation 7, bestfitness = 133.95
# Generation 8, bestfitness = 133.95
# Generation 9, bestfitness = 133.95
# Generation 10, bestfitness = 133.95
# Generation 11, bestfitness = 133.95
# Generation 12, bestfitness = 133.95
# Generation 13, bestfitness = 133.95
# Generation 14, bestfitness = 133.95
# Generation 15, bestfitness = 133.95
# Generation 16, bestfitness = 133.95
# Generation 17, bestfitness = 133.95
# Generation 18, bestfitness = 133.95
# Generation 19, bestfitness = 133.95
# Generation 20, bestfitness = 133.95
# Generation 21, bestfitness = 133.95
# Generation 22, bestfitness = 133.95
# Generation 23, bestfitness = 133.95
# Generation 24, bestfitness = 133.95
# Generation 25, bestfitness = 133.95
# Generation 26, bestfitness = 133.95
# Generation 27, bestfitness = 133.95
# Generation 28, bestfitness = 133.95
# Generation 29, bestfitness = 133.95
# Generation 30, bestfitness = 133.95
# Generation 31, bestfitness = 133.95
# Generation 32, bestfitness = 133.95
# Generation 33, bestfitness = 133.95
# Generation 34, bestfitness = 133.95
# Generation 35, bestfitness = 133.95
# Generation 36, bestfitness = 133.95
# Generation 37, bestfitness = 133.95
# Generation 38, bestfitness = 133.95
# Generation 39, bestfitness = 133.95
# Generation 40, bestfitness = 133.95
# Generation 41, bestfitness = 133.95
# Generation 42, bestfitness = 133.95
# Generation 43, bestfitness = 133.95
# Generation 44, bestfitness = 133.95
# Generation 45, bestfitness = 133.95
# Generation 46, bestfitness = 133.95
# Generation 47, bestfitness = 133.95
# Generation 48, bestfitness = 133.95
# Generation 49, bestfitness = 133.95
# Generation 50, bestfitness = 133.95
# Generation 51, bestfitness = 133.95
# Generation 52, bestfitness = 133.95
# Generation 53, bestfitness = 133.95
# Generation 54, bestfitness = 133.95
# Generation 55, bestfitness = 133.95
# Generation 56, bestfitness = 133.95
# Generation 57, bestfitness = 133.95
# Generation 58, bestfitness = 133.95
# Generation 59, bestfitness = 133.95
# Generation 60, bestfitness = 133.95
# Generation 61, bestfitness = 133.95
# Generation 62, bestfitness = 133.95
# Generation 63, bestfitness = 133.95
# Generation 64, bestfitness = 133.95
# Generation 65, bestfitness = 133.95
# Generation 66, bestfitness = 133.95
# Generation 67, bestfitness = 133.95
# Generation 68, bestfitness = 133.95
# Generation 69, bestfitness = 133.95
# Generation 70, bestfitness = 133.95
# Generation 71, bestfitness = 133.95
# Generation 72, bestfitness = 133.95
# Generation 73, bestfitness = 133.95
# Generation 74, bestfitness = 133.95
# Generation 75, bestfitness = 133.95
# Generation 76, bestfitness = 133.95
# Generation 77, bestfitness = 133.95
# Generation 78, bestfitness = 133.95
# Generation 79, bestfitness = 133.95
# Generation 80, bestfitness = 133.95
# Generation 81, bestfitness = 133.95
# Generation 82, bestfitness = 133.95
# Generation 83, bestfitness = 133.95
# Generation 84, bestfitness = 133.95
# Generation 85, bestfitness = 133.95
# Generation 86, bestfitness = 133.95
# Generation 87, bestfitness = 133.95
# Generation 88, bestfitness = 133.95
# Generation 89, bestfitness = 133.95
# Generation 90, bestfitness = 133.95
# Generation 91, bestfitness = 133.95
# Generation 92, bestfitness = 133.95
# Generation 93, bestfitness = 133.95
# Generation 94, bestfitness = 133.95
# Generation 95, bestfitness = 133.95
# Generation 96, bestfitness = 133.95
# Generation 97, bestfitness = 133.95
# Generation 98, bestfitness = 133.95
# Generation 99, bestfitness = 133.95
# Generation 100, bestfitness = 133.95
# Generation 101, bestfitness = 133.95
# Generation 102, bestfitness = 133.95
# Generation 103, bestfitness = 133.95
# Generation 104, bestfitness = 133.95
# Generation 105, bestfitness = 133.95
# Generation 106, bestfitness = 133.95
# Generation 107, bestfitness = 133.95
# Generation 108, bestfitness = 133.95
# Generation 109, bestfitness = 133.95
# Generation 110, bestfitness = 133.95
# Generation 111, bestfitness = 133.95
# Generation 112, bestfitness = 133.95
# Generation 113, bestfitness = 133.95
# Generation 114, bestfitness = 133.95
# Generation 115, bestfitness = 133.95
# Generation 116, bestfitness = 133.95
# Generation 117, bestfitness = 133.95
# Generation 118, bestfitness = 133.95
# Generation 119, bestfitness = 133.95
# Generation 120, bestfitness = 133.95
# Generation 121, bestfitness = 133.95
# Generation 122, bestfitness = 133.95
# Generation 123, bestfitness = 133.95
# Generation 124, bestfitness = 133.95
# Generation 125, bestfitness = 133.95
# Generation 126, bestfitness = 133.95
# Generation 127, bestfitness = 133.95
# Generation 128, bestfitness = 133.95
# Generation 129, bestfitness = 133.95
# Generation 130, bestfitness = 133.95
# Generation 131, bestfitness = 133.95
# Generation 132, bestfitness = 133.95
# Generation 133, bestfitness = 133.95
# Generation 134, bestfitness = 133.95
# Generation 135, bestfitness = 133.95
# Generation 136, bestfitness = 133.95
# Generation 137, bestfitness = 133.95
# Generation 138, bestfitness = 133.95
# Generation 139, bestfitness = 133.95
# Generation 140, bestfitness = 133.95
# Generation 141, bestfitness = 133.95
# Generation 142, bestfitness = 133.95
# Generation 143, bestfitness = 133.95
# Generation 144, bestfitness = 133.95
# Generation 145, bestfitness = 133.95
# Generation 146, bestfitness = 133.95
# Generation 147, bestfitness = 133.95
# Generation 148, bestfitness = 133.95
# Generation 149, bestfitness = 133.95
# Generation 150, bestfitness = 133.95
# Generation 151, bestfitness = 133.95
# Generation 152, bestfitness = 133.95
# Generation 153, bestfitness = 133.95
# Generation 154, bestfitness = 133.95
# Generation 155, bestfitness = 133.95
# Generation 156, bestfitness = 133.95
# Generation 157, bestfitness = 133.95
# Generation 158, bestfitness = 133.95
# Generation 159, bestfitness = 133.95
# Generation 160, bestfitness = 133.95
# Generation 161, bestfitness = 133.95
# Generation 162, bestfitness = 133.95
# Generation 163, bestfitness = 133.95
# Generation 164, bestfitness = 133.95
# Generation 165, bestfitness = 133.95
# Generation 166, bestfitness = 133.95
# Generation 167, bestfitness = 133.95
# Generation 168, bestfitness = 133.95
# Generation 169, bestfitness = 133.95
# Generation 170, bestfitness = 133.95
# Generation 171, bestfitness = 133.95
# Generation 172, bestfitness = 133.95
# Generation 173, bestfitness = 133.95
# Generation 174, bestfitness = 133.95
# Generation 175, bestfitness = 133.95
# Generation 176, bestfitness = 133.95
# Generation 177, bestfitness = 133.95
# Generation 178, bestfitness = 133.95
# Generation 179, bestfitness = 133.95
# Generation 180, bestfitness = 133.95
# Generation 181, bestfitness = 133.95
# Generation 182, bestfitness = 133.95
# Generation 183, bestfitness = 133.95
# Generation 184, bestfitness = 133.95
# Generation 185, bestfitness = 133.95
# Generation 186, bestfitness = 133.95
# Generation 187, bestfitness = 133.95
# Generation 188, bestfitness = 133.95
# Generation 189, bestfitness = 133.95
# Generation 190, bestfitness = 133.95
# Generation 191, bestfitness = 133.95
# Generation 192, bestfitness = 133.95
# Generation 193, bestfitness = 133.95
# Generation 194, bestfitness = 133.95
# Generation 195, bestfitness = 133.95
# Generation 196, bestfitness = 133.95
# Generation 197, bestfitness = 133.95
# Generation 198, bestfitness = 133.95
# Generation 199, bestfitness = 133.95
# Generation 200, bestfitness = 133.95
# Generation 201, bestfitness = 133.95
# Generation 202, bestfitness = 133.95
# Generation 203, bestfitness = 133.95
# Generation 204, bestfitness = 133.95
# Generation 205, bestfitness = 133.95
# Generation 206, bestfitness = 133.95
# Generation 207, bestfitness = 133.95
# Generation 208, bestfitness = 133.95
# Generation 209, bestfitness = 133.95
# Generation 210, bestfitness = 133.95
# Generation 211, bestfitness = 133.95
# Generation 212, bestfitness = 133.95
# Generation 213, bestfitness = 133.95
# Generation 214, bestfitness = 133.95
# Generation 215, bestfitness = 133.95
# Generation 216, bestfitness = 133.95
# Generation 217, bestfitness = 133.95
# Generation 218, bestfitness = 133.95
# Generation 219, bestfitness = 133.95
# Generation 220, bestfitness = 133.95
# Generation 221, bestfitness = 133.95
# Generation 222, bestfitness = 133.95
# Generation 223, bestfitness = 133.95
# Generation 224, bestfitness = 133.95
# Generation 225, bestfitness = 133.95
# Generation 226, bestfitness = 133.95
# Generation 227, bestfitness = 133.95
# Generation 228, bestfitness = 133.95
# Generation 229, bestfitness = 133.95
# Generation 230, bestfitness = 133.95
# Generation 231, bestfitness = 133.95
# Generation 232, bestfitness = 133.95
# Generation 233, bestfitness = 133.95
# Generation 234, bestfitness = 133.95
# Generation 235, bestfitness = 133.95
# Generation 236, bestfitness = 133.95
# Generation 237, bestfitness = 133.95
# Generation 238, bestfitness = 133.95
# Generation 239, bestfitness = 133.95
# Generation 240, bestfitness = 133.95
# Generation 241, bestfitness = 133.95
# Generation 242, bestfitness = 133.95
# Generation 243, bestfitness = 133.95
# Generation 244, bestfitness = 133.95
# Generation 245, bestfitness = 133.95
# Generation 246, bestfitness = 133.95
# Generation 247, bestfitness = 133.95
# Generation 248, bestfitness = 133.95
# Generation 249, bestfitness = 133.95
# Generation 250, bestfitness = 133.95
# Generation 251, bestfitness = 133.95
# Generation 252, bestfitness = 133.95
# Generation 253, bestfitness = 133.95
# Generation 254, bestfitness = 133.95
# Generation 255, bestfitness = 133.95
# Generation 256, bestfitness = 133.95
# Generation 257, bestfitness = 133.95
# Generation 258, bestfitness = 133.95
# Generation 259, bestfitness = 133.95
# Generation 260, bestfitness = 133.95
# Generation 261, bestfitness = 133.95
# Generation 262, bestfitness = 133.95
# Generation 263, bestfitness = 133.95
# Generation 264, bestfitness = 133.95
# Generation 265, bestfitness = 133.95
# Generation 266, bestfitness = 133.95
# Generation 267, bestfitness = 133.95
# Generation 268, bestfitness = 133.95
# Generation 269, bestfitness = 133.95
# Generation 270, bestfitness = 133.95
# Generation 271, bestfitness = 133.95
# Generation 272, bestfitness = 133.95
# Generation 273, bestfitness = 133.95
# Generation 274, bestfitness = 133.95
# Generation 275, bestfitness = 133.95
# Generation 276, bestfitness = 133.95
# Generation 277, bestfitness = 133.95
# Generation 278, bestfitness = 133.95
# Generation 279, bestfitness = 133.95
# Generation 280, bestfitness = 133.95
# Generation 281, bestfitness = 133.95
# Generation 282, bestfitness = 133.95
# Generation 283, bestfitness = 133.95
# Generation 284, bestfitness = 133.95
# Generation 285, bestfitness = 133.95
# Generation 286, bestfitness = 133.95
# Generation 287, bestfitness = 133.95
# Generation 288, bestfitness = 133.95
# Generation 289, bestfitness = 133.95
# Generation 290, bestfitness = 133.95
# Generation 291, bestfitness = 133.95
# Generation 292, bestfitness = 133.95
# Generation 293, bestfitness = 133.95
# Generation 294, bestfitness = 133.95
# Generation 295, bestfitness = 133.95
# Generation 296, bestfitness = 133.95
# Generation 297, bestfitness = 133.95
# Generation 298, bestfitness = 133.95
# Generation 299, bestfitness = 133.95
# Generation 300, bestfitness = 133.95
# Generation 301, bestfitness = 133.95
# Generation 302, bestfitness = 133.95
# Generation 303, bestfitness = 133.95
# Generation 304, bestfitness = 133.95
# Generation 305, bestfitness = 133.95
# Generation 306, bestfitness = 133.95
# Generation 307, bestfitness = 133.95
# Generation 308, bestfitness = 133.95
# Generation 309, bestfitness = 133.95
# Generation 310, bestfitness = 133.95
# Generation 311, bestfitness = 133.95
# Generation 312, bestfitness = 133.95
# Generation 313, bestfitness = 133.95
# Generation 314, bestfitness = 133.95
# Generation 315, bestfitness = 133.95
# Generation 316, bestfitness = 133.95
# Generation 317, bestfitness = 133.95
# Generation 318, bestfitness = 133.95
# Generation 319, bestfitness = 133.95
# Generation 320, bestfitness = 133.95
# Generation 321, bestfitness = 133.95
# Generation 322, bestfitness = 133.95
# Generation 323, bestfitness = 133.95
# Generation 324, bestfitness = 133.95
# Generation 325, bestfitness = 133.95
# Generation 326, bestfitness = 133.95
# Generation 327, bestfitness = 133.95
# Generation 328, bestfitness = 133.95
# Generation 329, bestfitness = 133.95
# Generation 330, bestfitness = 133.95
# Generation 331, bestfitness = 133.95
# Generation 332, bestfitness = 133.95
# Generation 333, bestfitness = 133.95
# Generation 334, bestfitness = 133.95
# Generation 335, bestfitness = 133.95
# Generation 336, bestfitness = 133.95
# Generation 337, bestfitness = 133.95
# Generation 338, bestfitness = 133.95
# Generation 339, bestfitness = 133.95
# Generation 340, bestfitness = 133.95
# Generation 341, bestfitness = 133.95
# Generation 342, bestfitness = 133.95
# Generation 343, bestfitness = 133.95
# Generation 344, bestfitness = 133.95
# Generation 345, bestfitness = 133.95
# Generation 346, bestfitness = 133.95
# Generation 347, bestfitness = 133.95
# Generation 348, bestfitness = 133.95
# Generation 349, bestfitness = 133.95
# Generation 350, bestfitness = 133.95
# Generation 351, bestfitness = 133.95
# Generation 352, bestfitness = 133.95
# Generation 353, bestfitness = 133.95
# Generation 354, bestfitness = 133.95
# Generation 355, bestfitness = 133.95
# Generation 356, bestfitness = 133.95
# Generation 357, bestfitness = 133.95
# Generation 358, bestfitness = 133.95
# Generation 359, bestfitness = 133.95
# Generation 360, bestfitness = 133.95
# Generation 361, bestfitness = 133.95
# Generation 362, bestfitness = 133.95
# Generation 363, bestfitness = 133.95
# Generation 364, bestfitness = 133.95
# Generation 365, bestfitness = 133.95
# Generation 366, bestfitness = 133.95
# Generation 367, bestfitness = 133.95
# Generation 368, bestfitness = 133.95
# Generation 369, bestfitness = 133.95
# Generation 370, bestfitness = 133.95
# Generation 371, bestfitness = 133.95
# Generation 372, bestfitness = 133.95
# Generation 373, bestfitness = 133.95
# Generation 374, bestfitness = 133.95
# Generation 375, bestfitness = 133.95
# Generation 376, bestfitness = 133.95
# Generation 377, bestfitness = 133.95
# Generation 378, bestfitness = 133.95
# Generation 379, bestfitness = 133.95
# Generation 380, bestfitness = 133.95
# Generation 381, bestfitness = 133.95
# Generation 382, bestfitness = 133.95
# Generation 383, bestfitness = 133.95
# Generation 384, bestfitness = 133.95
# Generation 385, bestfitness = 133.95
# Generation 386, bestfitness = 133.95
# Generation 387, bestfitness = 133.95
# Generation 388, bestfitness = 133.95
# Generation 389, bestfitness = 133.95
# Generation 390, bestfitness = 133.95
# Generation 391, bestfitness = 133.95
# Generation 392, bestfitness = 133.95
# Generation 393, bestfitness = 133.95
# Generation 394, bestfitness = 133.95
# Generation 395, bestfitness = 133.95
# Generation 396, bestfitness = 133.95
# Generation 397, bestfitness = 133.95
# Generation 398, bestfitness = 133.95
# Generation 399, bestfitness = 133.95
# Generation 400, bestfitness = 133.95
# Generation 401, bestfitness = 133.95
# Generation 402, bestfitness = 133.95
# Generation 403, bestfitness = 133.95
# Generation 404, bestfitness = 133.95
# Generation 405, bestfitness = 133.95
# Generation 406, bestfitness = 133.95
# Generation 407, bestfitness = 133.95
# Generation 408, bestfitness = 133.95
# Generation 409, bestfitness = 133.95
# Generation 410, bestfitness = 133.95
# Generation 411, bestfitness = 133.95
# Generation 412, bestfitness = 133.95
# Generation 413, bestfitness = 133.95
# Generation 414, bestfitness = 133.95
# Generation 415, bestfitness = 133.95
# Generation 416, bestfitness = 133.95
# Generation 417, bestfitness = 133.95
# Generation 418, bestfitness = 133.95
# Generation 419, bestfitness = 133.95
# Generation 420, bestfitness = 133.95
# Generation 421, bestfitness = 133.95
# Generation 422, bestfitness = 133.95
# Generation 423, bestfitness = 133.95
# Generation 424, bestfitness = 133.95
# Generation 425, bestfitness = 133.95
# Generation 426, bestfitness = 133.95
# Generation 427, bestfitness = 133.95
# Generation 428, bestfitness = 133.95
# Generation 429, bestfitness = 133.95
# Generation 430, bestfitness = 133.95
# Generation 431, bestfitness = 133.95
# Generation 432, bestfitness = 133.95
# Generation 433, bestfitness = 133.95
# Generation 434, bestfitness = 133.95
# Generation 435, bestfitness = 133.95
# Generation 436, bestfitness = 133.95
# Generation 437, bestfitness = 133.95
# Generation 438, bestfitness = 133.95
# Generation 439, bestfitness = 133.95
# Generation 440, bestfitness = 133.95
# Generation 441, bestfitness = 133.95
# Generation 442, bestfitness = 133.95
# Generation 443, bestfitness = 133.95
# Generation 444, bestfitness = 133.95
# Generation 445, bestfitness = 133.95
# Generation 446, bestfitness = 133.95
# Generation 447, bestfitness = 133.95
# Generation 448, bestfitness = 133.95
# Generation 449, bestfitness = 133.95
# Generation 450, bestfitness = 133.95
# Generation 451, bestfitness = 133.95
# Generation 452, bestfitness = 133.95
# Generation 453, bestfitness = 133.95
# Generation 454, bestfitness = 133.95
# Generation 455, bestfitness = 133.95
# Generation 456, bestfitness = 133.95
# Generation 457, bestfitness = 133.95
# Generation 458, bestfitness = 133.95
# Generation 459, bestfitness = 133.95
# Generation 460, bestfitness = 133.95
# Generation 461, bestfitness = 133.95
# Generation 462, bestfitness = 133.95
# Generation 463, bestfitness = 133.95
# Generation 464, bestfitness = 133.95
# Generation 465, bestfitness = 133.95
# Generation 466, bestfitness = 133.95
# Generation 467, bestfitness = 133.95
# Generation 468, bestfitness = 133.95
# Generation 469, bestfitness = 133.95
# Generation 470, bestfitness = 133.95
# Generation 471, bestfitness = 133.95
# Generation 472, bestfitness = 133.95
# Generation 473, bestfitness = 133.95
# Generation 474, bestfitness = 133.95
# Generation 475, bestfitness = 133.95
# Generation 476, bestfitness = 133.95
# Generation 477, bestfitness = 133.95
# Generation 478, bestfitness = 133.95
# Generation 479, bestfitness = 133.95
# Generation 480, bestfitness = 133.95
# Generation 481, bestfitness = 133.95
# Generation 482, bestfitness = 133.95
# Generation 483, bestfitness = 133.95
# Generation 484, bestfitness = 133.95
# Generation 485, bestfitness = 133.95
# Generation 486, bestfitness = 133.95
# Generation 487, bestfitness = 133.95
# Generation 488, bestfitness = 133.95
# Generation 489, bestfitness = 133.95
# Generation 490, bestfitness = 133.95
# Generation 491, bestfitness = 133.95
# Generation 492, bestfitness = 133.95
# Generation 493, bestfitness = 133.95
# Generation 494, bestfitness = 133.95
# Generation 495, bestfitness = 133.95
# Generation 496, bestfitness = 133.95
# Generation 497, bestfitness = 133.95
# Generation 498, bestfitness = 133.95
# Generation 499, bestfitness = 133.95

# %%
np.set_printoptions(precision=2, suppress=True)
print("problem:")
print(f"profit: {profit}")
print(f"weight: {weight}")
print(f"capacity = {capacity:.2f}")
print()
print("solution:")
print(decode(solution.chromosome))
print(f"total_profit =  {solution.fitness:.2f}")
print(f"total_weight = {np.sum(decode(solution.chromosome) * weight):.2f}")
# Out:
# problem:
# profit: [11.54 11.31 17.78 11.68 17.37  5.16 15.49 16.07 15.04 17.66]
# weight: [14.54  5.24 13.71 13.54 12.32 13.69  7.56 10.17 18.65 11.2 ]
# capacity = 119.31
#
# solution:
# [1 1 1 1 1 0 1 1 1 1]
# total_profit =  133.95
# total_weight = 106.94

# %%
generations = list(range(len(fitness_history)))
plt.figure(figsize=(10, 5))
plt.plot(generations, fitness_history, marker='o', linestyle='-', color='b', label='Best Fitness')

plt.xlabel("Generation")
plt.ylabel("Best Fitness")
plt.title("Fitness Progress Over Generations")
plt.legend()
plt.grid(True)
plt.show()
